# %%
import json 

from datetime import datetime, timedelta
from operator import index
from CandleStream import CandleStream 
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
# from calender_utils import *
import utils
import dataset
# import strategy 
import numpy as np
from indicators import Indicators
# import mplfinance as mpf
import os

EXCHANGE = 'NSE'
START_DATE = datetime(2025, 11, 1, 9, 10)
END_DATE = datetime(2025, 12, 26, 15, 30)
START_TIME = datetime(2025, 10, 20, 9, 15)
END_TIME = datetime(2025, 10, 20, 12, 30)
INTERVAL = "5min"
INDEX = 'Nifty 50'
TRAIL = False
stream = CandleStream()
ORGINDEXDF = None
SECTORS_DATA = {}
STOCKS_DATA = {}

MAX_NUMBER_OF_STOCKS_PER_DAY = 5
RISK = 0.005
CAPITAL = 200000
RPT = CAPITAL * RISK
DAILYRISK = RPT * MAX_NUMBER_OF_STOCKS_PER_DAY//2
LESSVOLATILESTOCK =  ['TCS', 'HDFCBANK', 'SBIN']

TRADE_HISTORY = {}

###Strategy Params to have a bias
INITIALRANGE_IN_MINUTES = 10
MOMENTUM_IN_LAST_MINUTES = 20
###
ALLSECTORS = None
with open("index_stock.json", "r") as f:
    ALLSECTORS = json.load(f)


class CandleRange:
    def __init__(self, high, low):
        self.high = high
        self.low = low
        

def bias_structure(
    df: pd.DataFrame,
    window: int = 50,
    body_max_frac: float = 0.3,     # body <= 30% of range
    wick_min_frac: float = 0.5,     # long wick >= 50% of range
    top_band_frac: float = 0.2,     # body must close in top 30% (bullish pin)
    bottom_band_frac: float = 0.2,  # body must close in bottom 30% (bearish pin)
    vol_norm_window: int = 10,
    vol_clip: float = 3.0           # cap normalized volume to reduce outlier influence
    ):
    """
    Expects df with columns: open, high, low, close, volume.
    Returns df with pin classifications and a rolling bias score in [-1, +1].
    """
    df = df.copy()

    # Basic geometry
    rng = (df['high'] - df['low']).replace(0, np.nan)
    body = (df['close'] - df['open']).abs()
    upper_wick = df['high'] - np.maximum(df['open'], df['close'])
    lower_wick = np.minimum(df['open'], df['close']) - df['low']

    # Where is close within the range? (0=low, 1=high)
    close_pos = (df['close'] - df['low']) / rng

    # Thresholds
    small_body = (body / rng) <= body_max_frac
    long_upper = (upper_wick / rng) >= wick_min_frac
    long_lower = (lower_wick / rng) >= wick_min_frac

    close_near_top = close_pos >= (1 - top_band_frac)
    close_near_bottom = close_pos <= bottom_band_frac

    # Classifications
    bullish_pin = small_body & long_lower & close_near_top
    bearish_pin = small_body & long_upper & close_near_bottom

    # Percent body move (helps rank strength; sign matters)
    ret_body = (df['close'] - df['open']) / df['open']

    # Volume normalization
    vol_ma = df['volume'].rolling(vol_norm_window, min_periods=1).mean()
    vol_norm = (df['volume'] / vol_ma).clip(lower=0, upper=vol_clip)

    # Assign pressure based on pin and signed return magnitude
    # (You could also use wick/body ratio as weight. Here we combine sign and volume.)
    buy_pressure = np.where(bullish_pin, vol_norm * np.maximum(ret_body, 0), 0.0)
    sell_pressure = np.where(bearish_pin, vol_norm * np.maximum(-ret_body, 0), 0.0)

    df['bullish_pin'] = bullish_pin
    df['bearish_pin'] = bearish_pin
    df['vol_norm'] = vol_norm
    df['buy_p'] = buy_pressure
    df['sell_p'] = sell_pressure

    # Rolling aggregates
    buy_sum = pd.Series(buy_pressure, index=df.index).rolling(window, min_periods=5).sum()
    sell_sum = pd.Series(sell_pressure, index=df.index).rolling(window, min_periods=5).sum()

    # Bias metrics
    spread = buy_sum - sell_sum
    spread_total = (buy_sum + sell_sum).replace(0, np.nan)

    # Final bias score in [-1, +1]
    bias_score = (spread / spread_total).fillna(0).clip(-1, 1)

    df['pin_bias_score'] = bias_score
    df['pin_buy_sum'] = buy_sum
    df['pin_sell_sum'] = sell_sum



def data_bulk_loader():
    global ORGINDEXDF
    ORGINDEXDF = dataset.get_data(stream, 'NSE', INDEX, utils.get_token(EXCHANGE, INDEX), START_DATE, END_DATE, INTERVAL)
    ORGINDEXDF = Indicators.ema(ORGINDEXDF, 9)
    ORGINDEXDF = Indicators.ema(ORGINDEXDF, 15)
    
    
    for sector, stocks in ALLSECTORS.items():
        sectordf = dataset.get_data(stream, 'NSE', sector, utils.get_token_for_index(EXCHANGE, sector), START_DATE, END_DATE, INTERVAL)
        if sectordf is None:
            print(f"Data not found for sector: {sector}")
        else:
            sectordf = Indicators.ema(sectordf, 9)
            sectordf = Indicators.ema(sectordf, 15)
            SECTORS_DATA[sector] = sectordf

        for symbol in stocks:
            stockdf = dataset.get_data(stream, 'NSE', symbol, utils.get_token(EXCHANGE, symbol + '-EQ'), START_DATE, END_DATE, INTERVAL)

            if stockdf is None:
                print(f"Data not found for stock: {symbol}")
            else:
                stockdf = Indicators.ema(stockdf, 9)
                stockdf = Indicators.ema(stockdf, 15)
                STOCKS_DATA[symbol] = stockdf
# Out:
# [I 251219 18:07:05 smartConnect:121] in pool

# %%
data_bulk_loader()
# Out:
# NSE Nifty 50 99926000 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE Nifty 50 99926000 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for Nifty 50 from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE NIFTY IT 99926008 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE NIFTY IT 99926008 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for NIFTY IT from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE LTIM 17818 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE LTIM 17818 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for LTIM from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE TECHM 13538 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE TECHM 13538 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for TECHM from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE WIPRO 3787 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE WIPRO 3787 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for WIPRO from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE OFSS 10738 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE OFSS 10738 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for OFSS from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE TCS 11536 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE TCS 11536 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for TCS from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE HCLTECH 7229 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE HCLTECH 7229 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for HCLTECH from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE INFY 1594 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE INFY 1594 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for INFY from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE PERSISTENT 18365 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE PERSISTENT 18365 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for PERSISTENT from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE COFORGE 11543 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE COFORGE 11543 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for COFORGE from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE MPHASIS 4503 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE MPHASIS 4503 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for MPHASIS from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE NIFTY PVT BANK 99926047 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE NIFTY PVT BANK 99926047 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for NIFTY PVT BANK from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE RBLBANK 18391 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE RBLBANK 18391 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for RBLBANK from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE IDFCFIRSTB 11184 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE IDFCFIRSTB 11184 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for IDFCFIRSTB from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE BANDHANBNK 2263 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE BANDHANBNK 2263 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for BANDHANBNK from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE YESBANK 11915 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE YESBANK 11915 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for YESBANK from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE FEDERALBNK 1023 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE FEDERALBNK 1023 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for FEDERALBNK from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE INDUSINDBK 5258 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE INDUSINDBK 5258 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for INDUSINDBK from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE AXISBANK 5900 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE AXISBANK 5900 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for AXISBANK from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE HDFCBANK 1333 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE HDFCBANK 1333 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for HDFCBANK from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE KOTAKBANK 1922 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE KOTAKBANK 1922 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for KOTAKBANK from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE ICICIBANK 4963 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE ICICIBANK 4963 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for ICICIBANK from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE NIFTY AUTO 99926029 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE NIFTY AUTO 99926029 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for NIFTY AUTO from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE MRF 2277 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE MRF 2277 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for MRF from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE ASHOKLEY 212 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE ASHOKLEY 212 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for ASHOKLEY from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE BALKRISIND 335 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE BALKRISIND 335 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for BALKRISIND from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE HEROMOTOCO 1348 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE HEROMOTOCO 1348 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for HEROMOTOCO from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE BOSCHLTD 2181 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE BOSCHLTD 2181 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for BOSCHLTD from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE EICHERMOT 910 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE EICHERMOT 910 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for EICHERMOT from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE EXIDEIND 676 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE EXIDEIND 676 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for EXIDEIND from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE BHARATFORG 422 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE BHARATFORG 422 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for BHARATFORG from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE BAJAJ-AUTO 16669 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE BAJAJ-AUTO 16669 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for BAJAJ-AUTO from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE TVSMOTOR 8479 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE TVSMOTOR 8479 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for TVSMOTOR from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE MARUTI 10999 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE MARUTI 10999 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for MARUTI from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE MOTHERSON 4204 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE MOTHERSON 4204 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for MOTHERSON from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE TATAMOTORS 3456 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE TATAMOTORS 3456 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for TATAMOTORS from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE M&M 2031 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE M&M 2031 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for M&M from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE TIINDIA 312 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE TIINDIA 312 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for TIINDIA from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE NIFTY METAL 99926030 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE NIFTY METAL 99926030 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for NIFTY METAL from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE NATIONALUM 6364 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE NATIONALUM 6364 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for NATIONALUM from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE NMDC 15332 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE NMDC 15332 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for NMDC from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE HINDCOPPER 17939 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE HINDCOPPER 17939 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for HINDCOPPER from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE SAIL 2963 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE SAIL 2963 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for SAIL from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE TATASTEEL 3499 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE TATASTEEL 3499 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for TATASTEEL from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE JINDALSTEL 6733 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE JINDALSTEL 6733 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for JINDALSTEL from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE JSL 11236 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE JSL 11236 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for JSL from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE HINDZINC 1424 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE HINDZINC 1424 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for HINDZINC from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE APLAPOLLO 25780 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE APLAPOLLO 25780 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for APLAPOLLO from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE JSWSTEEL 11723 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE JSWSTEEL 11723 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for JSWSTEEL from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE HINDALCO 1363 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE HINDALCO 1363 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for HINDALCO from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE VEDL 3063 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE VEDL 3063 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for VEDL from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE LLOYDSME 17313 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE LLOYDSME 17313 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for LLOYDSME from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE ADANIENT 25 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE ADANIENT 25 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for ADANIENT from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE WELCORP 11821 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE WELCORP 11821 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for WELCORP from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE FINNIFTY 99926037 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE FINNIFTY 99926037 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for FINNIFTY from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE RECLTD 15355 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE RECLTD 15355 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for RECLTD from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE PFC 14299 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE PFC 14299 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for PFC from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE BAJAJFINSV 16675 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE BAJAJFINSV 16675 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for BAJAJFINSV from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE SBILIFE 21808 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE SBILIFE 21808 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for SBILIFE from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE ICICIPRULI 18652 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE ICICIPRULI 18652 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for ICICIPRULI from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE HDFCLIFE 467 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE HDFCLIFE 467 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for HDFCLIFE from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE BAJFINANCE 317 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE BAJFINANCE 317 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for BAJFINANCE from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE MUTHOOTFIN 23650 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE MUTHOOTFIN 23650 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for MUTHOOTFIN from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE SHRIRAMFIN 4306 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE SHRIRAMFIN 4306 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for SHRIRAMFIN from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE JIOFIN 18143 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE JIOFIN 18143 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for JIOFIN from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE HDFCAMC 4244 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE HDFCAMC 4244 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for HDFCAMC from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE ICICIGI 21770 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE ICICIGI 21770 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for ICICIGI from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE LICHSGFIN 1997 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE LICHSGFIN 1997 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for LICHSGFIN from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE CHOLAFIN 685 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE CHOLAFIN 685 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for CHOLAFIN from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE SBICARD 17971 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE SBICARD 17971 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for SBICARD from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE NIFTY PHARMA 99926023 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE NIFTY PHARMA 99926023 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for NIFTY PHARMA from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE ABBOTINDIA 17903 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE ABBOTINDIA 17903 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for ABBOTINDIA from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE AJANTPHARM 8124 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE AJANTPHARM 8124 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for AJANTPHARM from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE MANKIND 15380 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE MANKIND 15380 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for MANKIND from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE BIOCON 11373 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE BIOCON 11373 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for BIOCON from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE DIVISLAB 10940 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE DIVISLAB 10940 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for DIVISLAB from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE ZYDUSLIFE 7929 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE ZYDUSLIFE 7929 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for ZYDUSLIFE from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE SUNPHARMA 3351 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE SUNPHARMA 3351 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for SUNPHARMA from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE NATCOPHARM 3918 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE NATCOPHARM 3918 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for NATCOPHARM from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE IPCALAB 1633 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE IPCALAB 1633 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for IPCALAB from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE LAURUSLABS 19234 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE LAURUSLABS 19234 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for LAURUSLABS from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE TORNTPHARM 3518 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE TORNTPHARM 3518 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for TORNTPHARM from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE LUPIN 10440 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE LUPIN 10440 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for LUPIN from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE GLENMARK 7406 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE GLENMARK 7406 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for GLENMARK from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE GLAND 1186 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE GLAND 1186 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for GLAND from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE AUROPHARMA 275 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE AUROPHARMA 275 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for AUROPHARMA from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE JBCHEPHARM 1726 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE JBCHEPHARM 1726 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for JBCHEPHARM from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE ALKEM 11703 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE ALKEM 11703 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for ALKEM from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE CIPLA 694 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE CIPLA 694 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for CIPLA from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE GRANULES 11872 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE GRANULES 11872 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for GRANULES from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE DRREDDY 881 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE DRREDDY 881 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for DRREDDY from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE FORTIS 14592 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE FORTIS 14592 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for FORTIS from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE SYNGENE 10243 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE SYNGENE 10243 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for SYNGENE from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE APOLLOHOSP 157 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE APOLLOHOSP 157 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for APOLLOHOSP from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# NSE MAXHEALTH 22377 2025-11-30 23:59:59
# 2025-11-30 23:59:59
# NSE MAXHEALTH 22377 2025-12-31 23:59:59
# 2025-12-31 23:59:59
# Syncing for MAXHEALTH from 2025-12-01 00:00:00 to 2025-12-31 23:59:59

# %%
# START_TIME = datetime(2025, 10, 20, 10, 10)
# END_TIME = datetime(2025, 10, 20, 11, 30)
TRADE_HISTORY = {}
TOPSECTORS = 2

# %%
TRADE_HISTORY = {}
TOPSECTORS = 5
def filter_data_by_date(df, date):
    filtered_df = df[df['date'] == date.date()]
    filtered_df.reset_index(inplace=True, drop =True)
    return filtered_df

def filter_data_by_time(df, start_time, end_time):
    filtered_df = df[(df['timestamp'].dt.time >= start_time) & (df['timestamp'].dt.time <= end_time)]
    filtered_df.reset_index(inplace=True, drop =True)
    return filtered_df

def get_minor_data(df, date, starttime, end_time):
    df = filter_data_by_date(df, date)
    if df.empty:
        return 
    df = filter_data_by_time(df, starttime, end_time)
    return df


import mplfinance as mpf
def save_image(symbol, date, entry, sl, target):
        df = STOCKS_DATA.get(symbol)
        df = filter_data_by_date(df, date)
        foldername = "-".join(str(date).split(':'))
        filename = symbol
        folderpath = f"samplesimages/{foldername}" 
        filepath = f"samplesimages/{foldername}/{filename}.jpg"
        os.makedirs(folderpath, exist_ok=True)
        df['time'] = pd.to_datetime(df['timestamp'])
        df.set_index('time', inplace=True)
        entry_m = pd.Series(entry, index=df.index)
        ema_plots = []
        ema_plots.append(mpf.make_addplot(entry_m, color='green', linestyle='-', width=3))
        
        sl_m = pd.Series(sl, index=df.index)
        ema_plots.append(mpf.make_addplot(sl_m, color='red', linestyle='-', width=5))

        mpf.plot(df, type='candle', style='charles', title=symbol,
                ylabel='Price',
                figsize=(32, 16),
                volume=True,
                addplot=ema_plots,
                savefig=dict(fname=filepath, dpi=100))
        
import math
def Intraday_breakouts(df, window):
    df['resistance'] = np.nan
    df['max'] = df['high'].cummax()
    df['isheighest'] = df['max'] == df['high']

    for i in range(len(df)):
        if i == len(df)-window:
            break

        if i == 0:
            right = df.iloc[i+1:i+window+1]
            curr = df.iloc[i]
            if curr['high'] > right['high'].max() and curr['isheighest']:
                df.loc[i, 'resistance'] = df.iloc[i]['high']
        
        else:
            left = df.iloc[max(i-window,0) : i+1]
            right = df.iloc[i : i+window+1]
            curr = df.iloc[i]
            if curr['high'] >= left['high'].max() and curr['high'] >= right['high'].max() and curr['isheighest']:
                df.loc[i, 'resistance'] = df.iloc[i]['high']

    df['resistance'] = df['resistance'].ffill()
    df['resistance'] = df['resistance'].shift(window)
    df = df.drop(columns = ['isheighest'])
    
    return df 


def fit_strategy(df, side, date, t):
    if side == 'bullish':
            df = Intraday_breakouts(df, 3)
            if df.iloc[-1]['breakout']:
                entry =  df.iloc[-1]['close']
                sl = df.iloc[-4:]['low'].min()
                target = entry + 3 * (entry - sl)
                quantity = RPT //math.ceil(abs(sl - entry))
                if quantity == 1:
                    return
                return {'entry' : entry, 'sl' : sl, 'target' : target, 'date' : date, 'time' : t, 'status' : True, 'side' : side, 'quantity' : quantity}
        
    if side == 'bearish':
            df = Intraday_breakdowns(df, 3)
            if df.iloc[-1]['breakdown']:
                entry =  df.iloc[-1]['close']
                sl = df.iloc[-3:]['high'].max()
                target = entry - 3 * (sl - entry)
                quantity = RPT //math.ceil(abs(sl - entry))
                if quantity == 1:
                    return
                return {'entry' : entry, 'sl' : sl, 'target' : target, 'date' : date, 'time' : t, 'status' : True, 'side': side, 'quantity' : quantity }



def manage_trades(stock, is_trade, curr_t, date):
    update_profit_state(curr_t)

    print(TRADE_HISTORY.keys())
    if stock in list(TRADE_HISTORY.keys()):
        print(f"Stock already present in Tradehistory why it came again  ->  {stock} ")
    netrpofit = 0
    totalnumberoftrades = 0
    for _, trade in TRADE_HISTORY.items():
        netrpofit += trade.get('profit', 0)
        totalnumberoftrades += 1

    # print('---------------------', stock, is_trade)

    if totalnumberoftrades > MAX_NUMBER_OF_STOCKS_PER_DAY:
        return 
    
    if netrpofit < -1 * DAILYRISK:
        return 
    


    print(f"At time {curr_t}, Total trades: {totalnumberoftrades}, Net profit: {netrpofit}")
    if totalnumberoftrades <= 1 :
        print(f"Placing {totalnumberoftrades + 1}rd trade at time {curr_t} as net profit {netrpofit} > RPT {RPT//2} in ---- {stock}")
        TRADE_HISTORY[stock] = is_trade
        save_image(stock, date, is_trade['entry'], is_trade['sl'], None)

    # elif totalnumberoftrades == 1 :
    #     if netrpofit > RPT//2:
    #         print(f"Placing {totalnumberoftrades + 1}nd trade at time {curr_t} as net profit {netrpofit} > RPT {RPT//2} in ---- {stock}")
    #         TRADE_HISTORY[stock] = is_trade
    #         save_image(stock, date, is_trade['entry'], is_trade['sl'], None)

    elif totalnumberoftrades == 2:
        if netrpofit > RPT:
            print(f"Placing {totalnumberoftrades + 1}rd trade at time {curr_t} as net profit {netrpofit} > RPT {RPT} in ---- {stock}")
            TRADE_HISTORY[stock] = is_trade
            save_image(stock, date, is_trade['entry'], is_trade['sl'], None)
    elif totalnumberoftrades == 3:
        if netrpofit > RPT * 2:
            save_image(stock, date, is_trade['entry'], is_trade['sl'], None)
            print(f"Placing {totalnumberoftrades + 1}rd trade at time {curr_t} as net profit {netrpofit} > RPT {RPT * 2} in ---- {stock}")
            TRADE_HISTORY[stock] = is_trade

    elif totalnumberoftrades >= 4:
        if netrpofit > RPT * 3:
            save_image(stock, date, is_trade['entry'], is_trade['sl'], None)
            print(f"Placing {totalnumberoftrades + 1}rd trade at time {curr_t} as net profit {netrpofit} > RPT {RPT * 3} in ---- {stock}")
            TRADE_HISTORY[stock] = is_trade
    

def update_profit_state(current_time):
    global TRADE_HISTORY
    hisotry_temp = TRADE_HISTORY.copy()

    for stock, trade in TRADE_HISTORY.items():
        stockdf = STOCKS_DATA.get(stock)
        if stockdf is None:
            print(f"This is not Possible as this trade already exists for stock : {stock} with trade \n {trade}")

        else:
            stockdf = get_minor_data(stockdf, trade['date'], START_TIME.time(), current_time)
            
            if trade['side'] == 'bullish' and trade['status'] == True:
                currhighprice = stockdf.iloc[-1]['high']
                currlowprice = stockdf.iloc[-1]['low']
                currcloseprice = stockdf.iloc[-1]['low']
                if currlowprice < trade['sl']:
                    profit = (trade['sl'] - trade['entry']) * trade['quantity']
                    hisotry_temp[stock]['status'] = False
                    hisotry_temp[stock]['exit_price'] = trade['sl']
                    hisotry_temp[stock]['notes'] = 'sl hit'
                    hisotry_temp[stock]['profit'] = profit
                elif currhighprice > trade['target'] and TRAIL == False: 
                    profit = (trade['target'] - trade['entry']) * trade['quantity']
                    hisotry_temp[stock]['status'] = False
                    hisotry_temp[stock]['exit_price'] = trade['target']
                    hisotry_temp[stock]['notes'] = 'target achieved'
                    hisotry_temp[stock]['profit'] = profit
                else:
                    profit = (currhighprice - trade['entry']) * trade['quantity']
                    hisotry_temp[stock]['profit'] = profit
                

                if TRAIL and hisotry_temp[stock]['status'] == True and trade['sl'] != trade['entry']:
                    new_sl = trade['entry']
                    if (currhighprice - trade['entry']) > 3*(trade['entry'] - trade['sl']):
                        hisotry_temp[stock]['sl'] = new_sl
                        hisotry_temp[stock]['SL_TRAILED'] = True


            if trade['side'] == 'bearish' and trade['status'] == True:
                currhighprice = stockdf.iloc[-1]['high']
                currlowprice = stockdf.iloc[-1]['low']
                currcloseprice = stockdf.iloc[-1]['close']
                
                if currhighprice > trade['sl']:
                    profit = (trade['entry'] - trade['sl']) * trade['quantity']
                    hisotry_temp[stock]['status'] = False
                    hisotry_temp[stock]['exit_price'] = trade['sl']
                    hisotry_temp[stock]['notes'] = 'sl hit' 
                    hisotry_temp[stock]['profit'] = profit
                elif currlowprice < trade['target'] and TRAIL == False:
                    profit = (trade['entry'] - trade['target']) * trade['quantity']
                    hisotry_temp[stock]['status'] = False
                    hisotry_temp[stock]['exit_price'] = trade['target']
                    hisotry_temp[stock]['notes'] = 'target achieved'
                    hisotry_temp[stock]['profit'] = profit
                else:
                    profit = (trade['entry'] - currlowprice) * trade['quantity']
                    hisotry_temp[stock]['profit'] = profit 

                if TRAIL and hisotry_temp[stock]['status'] == True and trade['sl'] != trade['entry']:
                    new_sl = trade['entry']
                    if (trade['entry'] - currlowprice) > 2*(trade['sl'] - trade['entry']):
                        hisotry_temp[stock]['sl'] = new_sl
                        hisotry_temp[stock]['SL_TRAILED'] = True

    TRADE_HISTORY = hisotry_temp.copy()

def trend(df, endtime, first_15_mins):
    df['bearcandle'] = (df['close'] < df['ema_9']) & (df['close'] < df['ema_15']) & (df['close'] < np.maximum(df['open'].shift(1), df['close'].shift(1))) 
    df['bullcandle'] = (df['close'] > df['ema_9']) & (df['close'] > df['ema_15']) & (df['close'] > np.minimum(df['open'].shift(1), df['close'].shift(1))) 
    df['side'] = np.where(df['bearcandle'] , 'bearish',
                          np.where(df['bullcandle'], 'bullish', ''))
    
    # if df.iloc[-1]['time'] == endtime.time():
    #     if df.iloc[-1]['close'] > first_15_mins['high'].max() and (df.iloc[-1]['side'] == 'bullish' or df.iloc[-2]['side'] == 'bullish' ):
    #         return "bullish"
        
    #     if df.iloc[-1]['close'] < first_15_mins['low'].min() and (df.iloc[-1]['side'] == 'bearish' or df.iloc[-2]['side'] == 'bearish'):
    #         return "bearish"        
    first_15_mins_avg = (first_15_mins['high'].max() + first_15_mins['low'].min())/2
    if df.iloc[-1]['time'] == endtime.time():
        if df.iloc[-1]['close'] > first_15_mins_avg and (df.iloc[-1]['side'] == 'bullish'):
            return "bullish"
        
        if df.iloc[-1]['close'] < first_15_mins_avg and (df.iloc[-1]['side'] == 'bearish'):
            return "bearish"   
        

def get_nifty_view(date, starttime, endtime):
    df = ORGINDEXDF.copy()
    df = filter_data_by_date(df, date)
    if df is None or len(df) == 0:
        return 
    df = filter_data_by_time(df, starttime.time(), endtime.time())
    df.reset_index(inplace = True, drop = True)
    first_15_mins = filter_data_by_time(df, starttime.time(), datetime(2025, 1,1, 9, 30).time())
    return trend(df, endtime, first_15_mins)
    

def get_change(symbol, date, starttime, endtime, side, what):
    df = None
    if what == 'sector':
        df = SECTORS_DATA.get(symbol)
    if what == 'stock':
        df = STOCKS_DATA.get(symbol)
    df = filter_data_by_date(df, date)
    if df is None or len(df) == 0:
        return None
    df = filter_data_by_time(df, starttime.time(), endtime.time())
    first_15_mins = filter_data_by_time(df, starttime.time(), datetime(2025, 1,1, 9, 30).time())
    if side == 'bullish' :
        daylow = df['low'].min()
        currprice = df.iloc[-1]['close']
        change = (currprice - daylow)/daylow * 100
        return round(change , 2), trend(df, endtime, first_15_mins)
    
    if side == 'bearish' :
        dayhigh = df['high'].max()
        currprice = df.iloc[-1]['close']
        change = (currprice - dayhigh)/dayhigh * 100
        return round(change , 2), trend(df, endtime, first_15_mins)
    

def get_stock_view(stock, date, starttime, endtime, side):
    df = SECTORS_DATA.get(stock)
    df = filter_data_by_date(df, date)
    if df is None or len(df) == 0:
        return 
    df = filter_data_by_time(df, starttime.time(), endtime.time())
    df.reset_index(inplace = True, drop = True)
    first_15_mins = filter_data_by_time(df, starttime.time(), datetime(2025, 1,1, 9, 30).time())
    return trend(df, endtime, first_15_mins)
    
def get_change_threshold(stock, side):
    if stock in LESSVOLATILESTOCK:
        if side == 'bullish':
            return 1
        else:
            return -1
    
    if side == 'bullish':
        return 2
    else:
        return -2
    
def Intraday_breakouts(df, window):
    df.reset_index(inplace=True, drop =True)
    df['resistance'] = np.nan
    df['max'] = df['high'].cummax()
    df['isheighest'] = df['max'] == df['high']

    for i in range(len(df)):
        if i == len(df)-window:
            break

        if i == 0:
            right = df.iloc[i+1:i+window+1]
            curr = df.iloc[i]
            if curr['high'] > right['high'].max() and curr['isheighest']:
                df.loc[i, 'resistance'] = df.iloc[i]['high']
        
        else:
            left = df.iloc[max(i-window,0) : i+1]
            right = df.iloc[i : i+window+1]
            curr = df.iloc[i]
            if curr['high'] >= left['high'].max() and curr['high'] >= right['high'].max() and curr['isheighest']:
                df.loc[i, 'resistance'] = df.iloc[i]['high']

    df['resistance'] = df['resistance'].ffill()
    df['resistance'] = df['resistance'].shift(window)
    df = df.drop(columns = ['isheighest'])
    df['breakout'] = (df['close'] > df['resistance']) & (df['high'].cummax().shift(1) == df['resistance'].shift(1))
    return df 

def Intraday_breakdowns(df, window):
    df.reset_index(inplace=True, drop =True)
    df['support'] = np.nan
    df['min'] = df['low'].cummin()
    df['islowest'] = df['min'] == df['low']

    for i in range(len(df)):
        if i == len(df)-window:
            break

        if i == 0:
            right = df.iloc[i+1:i+window+1]
            curr = df.iloc[i]
            if curr['low'] < right['low'].min() and curr['islowest']:
                df.loc[i, 'support'] = df.iloc[i]['low']
        
        else:
            left = df.iloc[max(i-window,0) : i+1]
            right = df.iloc[i : i+window+1]
            curr = df.iloc[i]
            if curr['low'] <= left['low'].min() and curr['low'] <= right['low'].min() and curr['islowest']:
                df.loc[i, 'support'] = df.iloc[i]['low']

    df['support'] = df['support'].ffill()
    df['support'] = df['support'].shift(window)
    df = df.drop(columns = ['islowest'])
    df['breakdown'] = (df['close'] < df['support']) & (df['low'].cummin().shift(1) == df['support'].shift(1))
    return df 


def day_trading(date):
    global TRADE_HISTORY
    '''This will do day trading for all stocks in index_stock.json for a given date'''
    print("Starting day trading for date:", date)
    timer = datetime(2025, 1, 1, 10, 0)
    if ORGINDEXDF is None:
        print(f"XXXXXXXXXXXXXXXXXXXXXXXXXXX           \n No index data for {date}: may be some issue check again")
    indexdf = filter_data_by_date(ORGINDEXDF.copy(), date)

    if indexdf is None or indexdf.empty:
        print(f"XXXXXXXXXXXXXXXXXXXXXXXXXXX           \n No index data for {date}: may be a holiday check again")
        return 
    # print(indexdf.iloc[-1]['date'])
    # return     
    trading_time_range = pd.date_range("10:00", "15:00", freq="5min")
    for timer in trading_time_range:
        niftyview = get_nifty_view(date, START_TIME, timer) 
        sectorialview = {}
        if niftyview is not None:
            for sector in ALLSECTORS:
                sectorchange = get_change(sector, date, START_TIME, timer, niftyview, 'sector')
                if sectorchange is not None:
                    sectorialview[sector] = sectorchange

            if niftyview == 'bearish':
                sectorialview = sorted(sectorialview.items(), key=lambda x: x[1][0])
                sectorialview = sectorialview[:TOPSECTORS]
        
                for sector, (sec_change, sec_trend) in sectorialview:
                    if sec_trend != niftyview:
                        continue    
                    allstocksview = {}
                    for stock in ALLSECTORS.get(sector):
                        stockchange = get_change(stock, date, START_TIME, timer, niftyview, 'stock')
                        if stockchange is not None:
                            allstocksview[stock] = stockchange
                    allstocksview = sorted(allstocksview.items(), key=lambda x: x[1][0])
       
                    for stock, (stock_change, stock_trend) in allstocksview:
                        # print('xxxxxxxxxxxxx   ', stock, TRADE_HISTORY.get(stock) )
                        if TRADE_HISTORY.get(stock) is not None:
                            continue
                        if stock_trend != niftyview:
                            continue

                        if stock_change < get_change_threshold(stock, stock_trend):
                            # print(f"{timer}    niftyview -> {niftyview}  :     {sector}  ->  {sec_trend}   ||   {stock}  ->  {stock_trend}")
                            df = STOCKS_DATA.get(stock)
                            df = filter_data_by_date(df, date)
                            if df is not None and  len(df) > 0:
                                df = filter_data_by_time(df, START_TIME.time(), timer.time())
                                istrade = fit_strategy(df, sec_trend, date, timer)
                                if istrade is None:
                                    continue
                                else:
                                    manage_trades(stock, istrade, timer.time(), date)
            if niftyview == 'bullish':
                sectorialview = sorted(sectorialview.items(), key=lambda x: x[1][0], reverse= True)
                for sector, (sec_change, sec_trend) in sectorialview:
                    if sec_trend != niftyview:
                        continue    
                    allstocksview = {}
                    for stock in ALLSECTORS.get(sector):
                        stockchange = get_change(stock, date, START_TIME, timer, niftyview, 'stock')
                        if stockchange is not None:
                            allstocksview[stock] = stockchange
                    allstocksview = sorted(allstocksview.items(), key=lambda x: x[1][0], reverse=True)
       
                    for stock, (stock_change, stock_trend) in allstocksview:
                        # print('xxxxxxxxxxxxx   ', stock, TRADE_HISTORY.get(stock) )
                        if TRADE_HISTORY.get(stock) is not None:
                            continue
                        if stock_trend != niftyview:
                            continue

                        if stock_change > get_change_threshold(stock, stock_trend):
                            # print(f"{timer}    niftyview -> {niftyview}  :     {sector}  ->  {sec_trend}   ||   {stock}  ->  {stock_trend}")
                            df = STOCKS_DATA.get(stock)
                            df = filter_data_by_date(df, date)
                            if df is not None and  len(df) > 0:
                                df = filter_data_by_time(df, START_TIME.time(), timer.time())
                                istrade = fit_strategy(df, sec_trend, date, timer)
                                if istrade is None:
                                    continue
                                else:
                                    manage_trades(stock, istrade, timer.time(), date)


        # print(timer, ' -> ' ,niftyview, ' :  ' ,  sectorialview)


        update_profit_state(timer.time())
    return

# %%
month = 11
year = 2025
TRAIL = False
dates = pd.date_range(start=datetime(year, month, 1), end=datetime(year, month + 1 , 30), freq="D")
newhistory = []

for date in dates:
    day_trading(date)
    for k, v in TRADE_HISTORY.items():
        v['stock'] = k
        newhistory.append(v)
    TRADE_HISTORY = {}
# Out:
# Starting day trading for date: 2025-11-01 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-11-01 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-11-02 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-11-02 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-11-03 00:00:00
# dict_keys([])
# At time 11:10:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 11:10:00 as net profit 0 > RPT 500.0 in ---- SAIL
# dict_keys(['SAIL'])
# At time 12:45:00, Total trades: 1, Net profit: -415.00000000000625
# Placing 2rd trade at time 12:45:00 as net profit -415.00000000000625 > RPT 500.0 in ---- IPCALAB
# dict_keys(['SAIL', 'IPCALAB'])
# At time 12:50:00, Total trades: 2, Net profit: 250.0000000000142
# dict_keys(['SAIL', 'IPCALAB'])
# At time 13:10:00, Total trades: 2, Net profit: 815.0000000000119
# dict_keys(['SAIL', 'IPCALAB'])
# At time 13:15:00, Total trades: 2, Net profit: 865.0000000000091
# Starting day trading for date: 2025-11-04 00:00:00
# dict_keys([])
# At time 10:10:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:10:00 as net profit 0 > RPT 500.0 in ---- GLAND
# dict_keys(['GLAND'])
# At time 10:40:00, Total trades: 1, Net profit: -378.0000000000041
# Placing 2rd trade at time 10:40:00 as net profit -378.0000000000041 > RPT 500.0 in ---- HINDCOPPER
# dict_keys(['GLAND', 'HINDCOPPER'])
# At time 11:05:00, Total trades: 2, Net profit: -20.500000000021146
# dict_keys(['GLAND', 'HINDCOPPER'])
# At time 11:10:00, Total trades: 2, Net profit: 24.999999999994316
# dict_keys(['GLAND', 'HINDCOPPER'])
# At time 11:35:00, Total trades: 2, Net profit: -303.99999999999636
# dict_keys(['GLAND', 'HINDCOPPER'])
# At time 11:55:00, Total trades: 2, Net profit: -53.99999999999636
# dict_keys(['GLAND', 'HINDCOPPER'])
# At time 12:25:00, Total trades: 2, Net profit: 595.9999999999809
# dict_keys(['GLAND', 'HINDCOPPER'])
# At time 14:00:00, Total trades: 2, Net profit: 771.0000000000491
# dict_keys(['GLAND', 'HINDCOPPER'])
# At time 14:05:00, Total trades: 2, Net profit: 771.0000000000491
# dict_keys(['GLAND', 'HINDCOPPER'])
# At time 14:20:00, Total trades: 2, Net profit: 771.0000000000491
# dict_keys(['GLAND', 'HINDCOPPER'])
# At time 14:40:00, Total trades: 2, Net profit: 771.0000000000491
# dict_keys(['GLAND', 'HINDCOPPER'])
# At time 14:45:00, Total trades: 2, Net profit: 771.0000000000491
# Starting day trading for date: 2025-11-05 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-11-05 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-11-06 00:00:00
# dict_keys([])
# At time 10:05:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:05:00 as net profit 0 > RPT 500.0 in ---- HINDCOPPER
# dict_keys(['HINDCOPPER'])
# At time 10:05:00, Total trades: 1, Net profit: 99.99999999999432
# Placing 2rd trade at time 10:05:00 as net profit 99.99999999999432 > RPT 500.0 in ---- ADANIENT
# dict_keys(['HINDCOPPER', 'ADANIENT'])
# At time 10:10:00, Total trades: 2, Net profit: 607.9300000000007
# dict_keys(['HINDCOPPER', 'ADANIENT'])
# At time 10:10:00, Total trades: 2, Net profit: 607.9300000000007
# dict_keys(['HINDCOPPER', 'ADANIENT'])
# At time 10:10:00, Total trades: 2, Net profit: 607.9300000000007
# dict_keys(['HINDCOPPER', 'ADANIENT'])
# At time 10:15:00, Total trades: 2, Net profit: 1579.7100000000148
# Placing 3rd trade at time 10:15:00 as net profit 1579.7100000000148 > RPT 1000.0 in ---- ZYDUSLIFE
# dict_keys(['HINDCOPPER', 'ADANIENT', 'ZYDUSLIFE'])
# At time 11:20:00, Total trades: 3, Net profit: 2720.3400000000106
# Placing 4rd trade at time 11:20:00 as net profit 2720.3400000000106 > RPT 2000.0 in ---- RECLTD
# dict_keys(['HINDCOPPER', 'ADANIENT', 'ZYDUSLIFE', 'RECLTD'])
# At time 11:30:00, Total trades: 4, Net profit: 2953.320000000002
# dict_keys(['HINDCOPPER', 'ADANIENT', 'ZYDUSLIFE', 'RECLTD'])
# At time 12:10:00, Total trades: 4, Net profit: 3685.6299999999765
# Placing 5rd trade at time 12:10:00 as net profit 3685.6299999999765 > RPT 3000.0 in ---- VEDL
# dict_keys(['HINDCOPPER', 'ADANIENT', 'ZYDUSLIFE', 'RECLTD', 'VEDL'])
# At time 12:10:00, Total trades: 5, Net profit: 3725.629999999974
# Placing 6rd trade at time 12:10:00 as net profit 3725.629999999974 > RPT 3000.0 in ---- EICHERMOT
# dict_keys(['HINDCOPPER', 'ADANIENT', 'ZYDUSLIFE', 'RECLTD', 'VEDL', 'EICHERMOT'])
# dict_keys(['HINDCOPPER', 'ADANIENT', 'ZYDUSLIFE', 'RECLTD', 'VEDL', 'EICHERMOT'])
# dict_keys(['HINDCOPPER', 'ADANIENT', 'ZYDUSLIFE', 'RECLTD', 'VEDL', 'EICHERMOT'])
# dict_keys(['HINDCOPPER', 'ADANIENT', 'ZYDUSLIFE', 'RECLTD', 'VEDL', 'EICHERMOT'])
# dict_keys(['HINDCOPPER', 'ADANIENT', 'ZYDUSLIFE', 'RECLTD', 'VEDL', 'EICHERMOT'])
# dict_keys(['HINDCOPPER', 'ADANIENT', 'ZYDUSLIFE', 'RECLTD', 'VEDL', 'EICHERMOT'])
# Starting day trading for date: 2025-11-07 00:00:00
# dict_keys([])
# At time 11:10:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 11:10:00 as net profit 0 > RPT 500.0 in ---- JINDALSTEL
# dict_keys(['JINDALSTEL'])
# At time 11:20:00, Total trades: 1, Net profit: -12.499999999988631
# Placing 2rd trade at time 11:20:00 as net profit -12.499999999988631 > RPT 500.0 in ---- ADANIENT
# dict_keys(['JINDALSTEL', 'ADANIENT'])
# At time 11:25:00, Total trades: 2, Net profit: -83.19999999999368
# dict_keys(['JINDALSTEL', 'ADANIENT'])
# At time 11:30:00, Total trades: 2, Net profit: 21.450000000004366
# dict_keys(['JINDALSTEL', 'ADANIENT'])
# At time 11:30:00, Total trades: 2, Net profit: 21.450000000004366
# dict_keys(['JINDALSTEL', 'ADANIENT'])
# At time 11:30:00, Total trades: 2, Net profit: 21.450000000004366
# dict_keys(['JINDALSTEL', 'ADANIENT'])
# At time 12:15:00, Total trades: 2, Net profit: -469.6000000000083
# dict_keys(['JINDALSTEL', 'ADANIENT'])
# At time 12:15:00, Total trades: 2, Net profit: -469.6000000000083
# dict_keys(['JINDALSTEL', 'ADANIENT'])
# At time 12:30:00, Total trades: 2, Net profit: -216.00000000001842
# dict_keys(['JINDALSTEL', 'ADANIENT'])
# At time 12:35:00, Total trades: 2, Net profit: -101.64999999999054
# dict_keys(['JINDALSTEL', 'ADANIENT'])
# At time 12:40:00, Total trades: 2, Net profit: 57.34999999999104
# dict_keys(['JINDALSTEL', 'ADANIENT'])
# At time 12:40:00, Total trades: 2, Net profit: 57.34999999999104
# dict_keys(['JINDALSTEL', 'ADANIENT'])
# At time 12:45:00, Total trades: 2, Net profit: 682.3000000000025
# dict_keys(['JINDALSTEL', 'ADANIENT'])
# At time 13:00:00, Total trades: 2, Net profit: 1478.0500000000063
# Placing 3rd trade at time 13:00:00 as net profit 1478.0500000000063 > RPT 1000.0 in ---- NATIONALUM
# dict_keys(['JINDALSTEL', 'ADANIENT', 'NATIONALUM'])
# At time 13:25:00, Total trades: 3, Net profit: 2370.799999999995
# Placing 4rd trade at time 13:25:00 as net profit 2370.799999999995 > RPT 2000.0 in ---- ICICIGI
# dict_keys(['JINDALSTEL', 'ADANIENT', 'NATIONALUM', 'ICICIGI'])
# At time 13:30:00, Total trades: 4, Net profit: 3723.2999999999915
# Placing 5rd trade at time 13:30:00 as net profit 3723.2999999999915 > RPT 3000.0 in ---- M&M
# dict_keys(['JINDALSTEL', 'ADANIENT', 'NATIONALUM', 'ICICIGI', 'M&M'])
# At time 13:30:00, Total trades: 5, Net profit: 3778.2999999999915
# Placing 6rd trade at time 13:30:00 as net profit 3778.2999999999915 > RPT 3000.0 in ---- MUTHOOTFIN
# dict_keys(['JINDALSTEL', 'ADANIENT', 'NATIONALUM', 'ICICIGI', 'M&M', 'MUTHOOTFIN'])
# dict_keys(['JINDALSTEL', 'ADANIENT', 'NATIONALUM', 'ICICIGI', 'M&M', 'MUTHOOTFIN'])
# dict_keys(['JINDALSTEL', 'ADANIENT', 'NATIONALUM', 'ICICIGI', 'M&M', 'MUTHOOTFIN'])
# Starting day trading for date: 2025-11-08 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-11-08 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-11-09 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-11-09 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-11-10 00:00:00
# dict_keys([])
# At time 10:55:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:55:00 as net profit 0 > RPT 500.0 in ---- CHOLAFIN
# dict_keys(['CHOLAFIN'])
# At time 11:05:00, Total trades: 1, Net profit: 1109.999999999991
# Placing 2rd trade at time 11:05:00 as net profit 1109.999999999991 > RPT 500.0 in ---- TCS
# dict_keys(['CHOLAFIN', 'TCS'])
# At time 11:10:00, Total trades: 2, Net profit: 1138.9999999999864
# Placing 3rd trade at time 11:10:00 as net profit 1138.9999999999864 > RPT 1000.0 in ---- MPHASIS
# dict_keys(['CHOLAFIN', 'TCS', 'MPHASIS'])
# At time 12:45:00, Total trades: 3, Net profit: -165.00000000002274
# dict_keys(['CHOLAFIN', 'TCS', 'MPHASIS'])
# At time 13:25:00, Total trades: 3, Net profit: -555.0000000000318
# dict_keys(['CHOLAFIN', 'TCS', 'MPHASIS'])
# At time 14:20:00, Total trades: 3, Net profit: 714.9999999999727
# dict_keys(['CHOLAFIN', 'TCS', 'MPHASIS'])
# At time 14:20:00, Total trades: 3, Net profit: 714.9999999999727
# Starting day trading for date: 2025-11-11 00:00:00
# dict_keys([])
# At time 10:35:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:35:00 as net profit 0 > RPT 500.0 in ---- SBICARD
# dict_keys(['SBICARD'])
# At time 10:35:00, Total trades: 1, Net profit: 116.19999999998868
# Placing 2rd trade at time 10:35:00 as net profit 116.19999999998868 > RPT 500.0 in ---- HDFCBANK
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 10:35:00, Total trades: 2, Net profit: 516.2000000000228
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 11:10:00, Total trades: 2, Net profit: -684.6000000000038
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 11:10:00, Total trades: 2, Net profit: -684.6000000000038
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 11:10:00, Total trades: 2, Net profit: -684.6000000000038
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 11:10:00, Total trades: 2, Net profit: -684.6000000000038
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 12:30:00, Total trades: 2, Net profit: -493.70000000000755
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 13:10:00, Total trades: 2, Net profit: -203.20000000000755
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 13:20:00, Total trades: 2, Net profit: -759.3000000000113
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 13:40:00, Total trades: 2, Net profit: -792.5
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 13:45:00, Total trades: 2, Net profit: -983.4000000000151
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 13:45:00, Total trades: 2, Net profit: -983.4000000000151
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 13:50:00, Total trades: 2, Net profit: -1099.6000000000038
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 14:05:00, Total trades: 2, Net profit: -991.7000000000075
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 14:05:00, Total trades: 2, Net profit: -991.7000000000075
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 14:25:00, Total trades: 2, Net profit: -634.8000000000113
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 14:30:00, Total trades: 2, Net profit: -767.6000000000038
# dict_keys(['SBICARD', 'HDFCBANK'])
# At time 14:30:00, Total trades: 2, Net profit: -767.6000000000038
# Starting day trading for date: 2025-11-12 00:00:00
# dict_keys([])
# At time 11:00:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 11:00:00 as net profit 0 > RPT 500.0 in ---- TIINDIA
# dict_keys(['TIINDIA'])
# At time 11:20:00, Total trades: 1, Net profit: 285.19999999999436
# Placing 2rd trade at time 11:20:00 as net profit 285.19999999999436 > RPT 500.0 in ---- LTIM
# dict_keys(['TIINDIA', 'LTIM'])
# At time 11:45:00, Total trades: 2, Net profit: 1950.6999999999944
# Placing 3rd trade at time 11:45:00 as net profit 1950.6999999999944 > RPT 1000.0 in ---- BIOCON
# dict_keys(['TIINDIA', 'LTIM', 'BIOCON'])
# At time 12:55:00, Total trades: 3, Net profit: 949.7499999999986
# dict_keys(['TIINDIA', 'LTIM', 'BIOCON'])
# At time 13:00:00, Total trades: 3, Net profit: 1001.4499999999915
# Starting day trading for date: 2025-11-13 00:00:00
# dict_keys([])
# At time 10:35:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:35:00 as net profit 0 > RPT 500.0 in ---- INDUSINDBK
# dict_keys(['INDUSINDBK'])
# At time 10:35:00, Total trades: 1, Net profit: 198.80000000001291
# Placing 2rd trade at time 10:35:00 as net profit 198.80000000001291 > RPT 500.0 in ---- BIOCON
# dict_keys(['INDUSINDBK', 'BIOCON'])
# At time 10:40:00, Total trades: 2, Net profit: 333.7000000000113
# dict_keys(['INDUSINDBK', 'BIOCON'])
# At time 11:00:00, Total trades: 2, Net profit: 1242.5000000000082
# Placing 3rd trade at time 11:00:00 as net profit 1242.5000000000082 > RPT 1000.0 in ---- ICICIBANK
# dict_keys(['INDUSINDBK', 'BIOCON', 'ICICIBANK'])
# At time 12:05:00, Total trades: 3, Net profit: 496.5000000000308
# dict_keys(['INDUSINDBK', 'BIOCON', 'ICICIBANK'])
# At time 12:55:00, Total trades: 3, Net profit: 457.20000000010214
# Starting day trading for date: 2025-11-14 00:00:00
# dict_keys([])
# At time 10:30:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:30:00 as net profit 0 > RPT 500.0 in ---- ASHOKLEY
# dict_keys(['ASHOKLEY'])
# At time 10:55:00, Total trades: 1, Net profit: -84.99999999999375
# Placing 2rd trade at time 10:55:00 as net profit -84.99999999999375 > RPT 500.0 in ---- ADANIENT
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 10:55:00, Total trades: 2, Net profit: -38.800000000003934
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 11:10:00, Total trades: 2, Net profit: 321.480000000005
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 11:10:00, Total trades: 2, Net profit: 321.480000000005
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 11:45:00, Total trades: 2, Net profit: 462.9600000000032
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 12:30:00, Total trades: 2, Net profit: 252.72000000000355
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 12:30:00, Total trades: 2, Net profit: 252.72000000000355
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 12:30:00, Total trades: 2, Net profit: 252.72000000000355
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 12:55:00, Total trades: 2, Net profit: 549.9200000000055
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 13:00:00, Total trades: 2, Net profit: 593.4000000000037
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 13:00:00, Total trades: 2, Net profit: 593.4000000000037
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 13:30:00, Total trades: 2, Net profit: 649.5199999999913
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 13:40:00, Total trades: 2, Net profit: 755.0000000000097
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 13:40:00, Total trades: 2, Net profit: 755.0000000000097
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 13:50:00, Total trades: 2, Net profit: 740.0000000000091
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 14:20:00, Total trades: 2, Net profit: 769.6800000000042
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 14:50:00, Total trades: 2, Net profit: 515.3199999999905
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 14:55:00, Total trades: 2, Net profit: 368.00000000000796
# dict_keys(['ASHOKLEY', 'ADANIENT'])
# At time 15:00:00, Total trades: 2, Net profit: 517.1200000000047
# Starting day trading for date: 2025-11-15 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-11-15 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-11-16 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-11-16 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-11-17 00:00:00
# dict_keys([])
# At time 10:15:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:15:00 as net profit 0 > RPT 500.0 in ---- HEROMOTOCO
# dict_keys(['HEROMOTOCO'])
# At time 10:25:00, Total trades: 1, Net profit: 350.0
# Placing 2rd trade at time 10:25:00 as net profit 350.0 > RPT 500.0 in ---- MPHASIS
# dict_keys(['HEROMOTOCO', 'MPHASIS'])
# At time 11:05:00, Total trades: 2, Net profit: 1977.0000000000164
# Placing 3rd trade at time 11:05:00 as net profit 1977.0000000000164 > RPT 1000.0 in ---- YESBANK
# dict_keys(['HEROMOTOCO', 'MPHASIS', 'YESBANK'])
# At time 11:20:00, Total trades: 3, Net profit: 3589.499999999974
# Placing 4rd trade at time 11:20:00 as net profit 3589.499999999974 > RPT 2000.0 in ---- ALKEM
# dict_keys(['HEROMOTOCO', 'MPHASIS', 'YESBANK', 'ALKEM'])
# At time 12:40:00, Total trades: 4, Net profit: 3356.9999999999736
# Placing 5rd trade at time 12:40:00 as net profit 3356.9999999999736 > RPT 3000.0 in ---- NATCOPHARM
# dict_keys(['HEROMOTOCO', 'MPHASIS', 'YESBANK', 'ALKEM', 'NATCOPHARM'])
# At time 12:50:00, Total trades: 5, Net profit: 3313.249999999968
# Placing 6rd trade at time 12:50:00 as net profit 3313.249999999968 > RPT 3000.0 in ---- LAURUSLABS
# dict_keys(['HEROMOTOCO', 'MPHASIS', 'YESBANK', 'ALKEM', 'NATCOPHARM', 'LAURUSLABS'])
# Starting day trading for date: 2025-11-18 00:00:00
# dict_keys([])
# At time 10:10:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:10:00 as net profit 0 > RPT 500.0 in ---- GLENMARK
# dict_keys(['GLENMARK'])
# At time 10:25:00, Total trades: 1, Net profit: 33.0
# Placing 2rd trade at time 10:25:00 as net profit 33.0 > RPT 500.0 in ---- HINDCOPPER
# dict_keys(['GLENMARK', 'HINDCOPPER'])
# At time 10:30:00, Total trades: 2, Net profit: 300.00000000001137
# dict_keys(['GLENMARK', 'HINDCOPPER'])
# At time 12:30:00, Total trades: 2, Net profit: -184.39999999999463
# dict_keys(['GLENMARK', 'HINDCOPPER'])
# At time 14:30:00, Total trades: 2, Net profit: -1002.7999999999856
# dict_keys(['GLENMARK', 'HINDCOPPER'])
# At time 14:45:00, Total trades: 2, Net profit: -1339.3999999999946
# Starting day trading for date: 2025-11-19 00:00:00
# dict_keys([])
# At time 10:05:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:05:00 as net profit 0 > RPT 500.0 in ---- PERSISTENT
# dict_keys(['PERSISTENT'])
# At time 10:05:00, Total trades: 1, Net profit: 90.0
# Placing 2rd trade at time 10:05:00 as net profit 90.0 > RPT 500.0 in ---- COFORGE
# dict_keys(['PERSISTENT', 'COFORGE'])
# At time 10:50:00, Total trades: 2, Net profit: -243.0
# dict_keys(['PERSISTENT', 'COFORGE'])
# At time 10:50:00, Total trades: 2, Net profit: -243.0
# dict_keys(['PERSISTENT', 'COFORGE'])
# At time 11:25:00, Total trades: 2, Net profit: 1450.799999999995
# Placing 3rd trade at time 11:25:00 as net profit 1450.799999999995 > RPT 1000.0 in ---- LTIM
# dict_keys(['PERSISTENT', 'COFORGE', 'LTIM'])
# At time 11:25:00, Total trades: 3, Net profit: 1483.799999999995
# dict_keys(['PERSISTENT', 'COFORGE', 'LTIM'])
# At time 11:55:00, Total trades: 3, Net profit: 3473.7999999999947
# Placing 4rd trade at time 11:55:00 as net profit 3473.7999999999947 > RPT 2000.0 in ---- HCLTECH
# dict_keys(['PERSISTENT', 'COFORGE', 'LTIM', 'HCLTECH'])
# At time 12:15:00, Total trades: 4, Net profit: 4391.800000000004
# Placing 5rd trade at time 12:15:00 as net profit 4391.800000000004 > RPT 3000.0 in ---- WIPRO
# dict_keys(['PERSISTENT', 'COFORGE', 'LTIM', 'HCLTECH', 'WIPRO'])
# At time 12:20:00, Total trades: 5, Net profit: 4422.200000000004
# Placing 6rd trade at time 12:20:00 as net profit 4422.200000000004 > RPT 3000.0 in ---- OFSS
# dict_keys(['PERSISTENT', 'COFORGE', 'LTIM', 'HCLTECH', 'WIPRO', 'OFSS'])
# dict_keys(['PERSISTENT', 'COFORGE', 'LTIM', 'HCLTECH', 'WIPRO', 'OFSS'])
# dict_keys(['PERSISTENT', 'COFORGE', 'LTIM', 'HCLTECH', 'WIPRO', 'OFSS'])
# Starting day trading for date: 2025-11-20 00:00:00
# dict_keys([])
# At time 10:40:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:40:00 as net profit 0 > RPT 500.0 in ---- TECHM
# dict_keys(['TECHM'])
# At time 13:40:00, Total trades: 1, Net profit: -124.5
# Placing 2rd trade at time 13:40:00 as net profit -124.5 > RPT 500.0 in ---- BAJAJFINSV
# dict_keys(['TECHM', 'BAJAJFINSV'])
# At time 14:20:00, Total trades: 2, Net profit: 788.5000000000189
# Starting day trading for date: 2025-11-21 00:00:00
# dict_keys([])
# At time 10:25:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:25:00 as net profit 0 > RPT 500.0 in ---- SAIL
# dict_keys(['SAIL'])
# At time 12:50:00, Total trades: 1, Net profit: -469.99999999999886
# Placing 2rd trade at time 12:50:00 as net profit -469.99999999999886 > RPT 500.0 in ---- INDUSINDBK
# dict_keys(['SAIL', 'INDUSINDBK'])
# At time 13:15:00, Total trades: 2, Net profit: -44.999999999987494
# dict_keys(['SAIL', 'INDUSINDBK'])
# At time 13:45:00, Total trades: 2, Net profit: 855.0000000000182
# dict_keys(['SAIL', 'INDUSINDBK'])
# At time 14:50:00, Total trades: 2, Net profit: 80.0000000000125
# dict_keys(['SAIL', 'INDUSINDBK'])
# At time 14:50:00, Total trades: 2, Net profit: 80.0000000000125
# dict_keys(['SAIL', 'INDUSINDBK'])
# At time 14:55:00, Total trades: 2, Net profit: 30.000000000001137
# dict_keys(['SAIL', 'INDUSINDBK'])
# At time 14:55:00, Total trades: 2, Net profit: 30.000000000001137
# dict_keys(['SAIL', 'INDUSINDBK'])
# At time 14:55:00, Total trades: 2, Net profit: 30.000000000001137
# dict_keys(['SAIL', 'INDUSINDBK'])
# At time 14:55:00, Total trades: 2, Net profit: 30.000000000001137
# dict_keys(['SAIL', 'INDUSINDBK'])
# At time 14:55:00, Total trades: 2, Net profit: 30.000000000001137
# dict_keys(['SAIL', 'INDUSINDBK'])
# At time 14:55:00, Total trades: 2, Net profit: 30.000000000001137
# Starting day trading for date: 2025-11-22 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-11-22 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-11-23 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-11-23 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-11-24 00:00:00
# dict_keys([])
# At time 10:35:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:35:00 as net profit 0 > RPT 500.0 in ---- SBICARD
# dict_keys(['SBICARD'])
# At time 11:55:00, Total trades: 1, Net profit: -920.0000000000045
# Placing 2rd trade at time 11:55:00 as net profit -920.0000000000045 > RPT 500.0 in ---- HINDCOPPER
# dict_keys(['SBICARD', 'HINDCOPPER'])
# At time 12:25:00, Total trades: 2, Net profit: -170.00000000000455
# dict_keys(['SBICARD', 'HINDCOPPER'])
# At time 14:25:00, Total trades: 2, Net profit: 29.999999999984084
# dict_keys(['SBICARD', 'HINDCOPPER'])
# At time 14:30:00, Total trades: 2, Net profit: -19.999999999998863
# dict_keys(['SBICARD', 'HINDCOPPER'])
# At time 14:35:00, Total trades: 2, Net profit: 154.99999999998408
# dict_keys(['SBICARD', 'HINDCOPPER'])
# At time 14:35:00, Total trades: 2, Net profit: 154.99999999998408
# dict_keys(['SBICARD', 'HINDCOPPER'])
# At time 14:35:00, Total trades: 2, Net profit: 154.99999999998408
# dict_keys(['SBICARD', 'HINDCOPPER'])
# At time 14:35:00, Total trades: 2, Net profit: 154.99999999998408
# Starting day trading for date: 2025-11-25 00:00:00
# dict_keys([])
# At time 10:20:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:20:00 as net profit 0 > RPT 500.0 in ---- HINDALCO
# dict_keys(['HINDALCO'])
# At time 10:55:00, Total trades: 1, Net profit: -979.3999999999962
# Placing 2rd trade at time 10:55:00 as net profit -979.3999999999962 > RPT 500.0 in ---- HDFCBANK
# dict_keys(['HINDALCO', 'HDFCBANK'])
# At time 13:25:00, Total trades: 2, Net profit: -1841.9000000000076
# dict_keys(['HINDALCO', 'HDFCBANK'])
# At time 14:05:00, Total trades: 2, Net profit: -1841.9000000000076
# dict_keys(['HINDALCO', 'HDFCBANK'])
# At time 14:10:00, Total trades: 2, Net profit: -1841.9000000000076
# Starting day trading for date: 2025-11-26 00:00:00
# dict_keys([])
# At time 10:05:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:05:00 as net profit 0 > RPT 500.0 in ---- BAJFINANCE
# dict_keys(['BAJFINANCE'])
# At time 10:40:00, Total trades: 1, Net profit: -116.20000000000755
# Placing 2rd trade at time 10:40:00 as net profit -116.20000000000755 > RPT 500.0 in ---- JSWSTEEL
# dict_keys(['BAJFINANCE', 'JSWSTEEL'])
# At time 10:50:00, Total trades: 2, Net profit: 482.3999999999962
# dict_keys(['BAJFINANCE', 'JSWSTEEL'])
# At time 11:05:00, Total trades: 2, Net profit: 506.5999999999924
# dict_keys(['BAJFINANCE', 'JSWSTEEL'])
# At time 11:25:00, Total trades: 2, Net profit: 634.9000000000076
# dict_keys(['BAJFINANCE', 'JSWSTEEL'])
# At time 12:00:00, Total trades: 2, Net profit: 1403.2000000000075
# Placing 3rd trade at time 12:00:00 as net profit 1403.2000000000075 > RPT 1000.0 in ---- CHOLAFIN
# dict_keys(['BAJFINANCE', 'JSWSTEEL', 'CHOLAFIN'])
# At time 12:35:00, Total trades: 3, Net profit: 1914.5000000000057
# dict_keys(['BAJFINANCE', 'JSWSTEEL', 'CHOLAFIN'])
# At time 13:00:00, Total trades: 3, Net profit: 1523.5000000000114
# dict_keys(['BAJFINANCE', 'JSWSTEEL', 'CHOLAFIN'])
# At time 13:05:00, Total trades: 3, Net profit: 1506.500000000017
# dict_keys(['BAJFINANCE', 'JSWSTEEL', 'CHOLAFIN'])
# At time 13:15:00, Total trades: 3, Net profit: 1356.5000000000114
# dict_keys(['BAJFINANCE', 'JSWSTEEL', 'CHOLAFIN'])
# At time 14:00:00, Total trades: 3, Net profit: 1421.700000000036
# dict_keys(['BAJFINANCE', 'JSWSTEEL', 'CHOLAFIN'])
# At time 14:05:00, Total trades: 3, Net profit: 1492.8000000000095
# dict_keys(['BAJFINANCE', 'JSWSTEEL', 'CHOLAFIN'])
# At time 14:05:00, Total trades: 3, Net profit: 1492.8000000000095
# dict_keys(['BAJFINANCE', 'JSWSTEEL', 'CHOLAFIN'])
# At time 15:00:00, Total trades: 3, Net profit: 1177.0000000000225
# Starting day trading for date: 2025-11-27 00:00:00
# dict_keys([])
# At time 11:45:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 11:45:00 as net profit 0 > RPT 500.0 in ---- LLOYDSME
# dict_keys(['LLOYDSME'])
# At time 12:25:00, Total trades: 1, Net profit: 999.0
# Placing 2rd trade at time 12:25:00 as net profit 999.0 > RPT 500.0 in ---- TIINDIA
# dict_keys(['LLOYDSME', 'TIINDIA'])
# At time 12:35:00, Total trades: 2, Net profit: 141.2999999999697
# dict_keys(['LLOYDSME', 'TIINDIA'])
# At time 13:10:00, Total trades: 2, Net profit: -1166.3999999999767
# dict_keys(['LLOYDSME', 'TIINDIA'])
# At time 13:10:00, Total trades: 2, Net profit: -1166.3999999999767
# dict_keys(['LLOYDSME', 'TIINDIA'])
# At time 14:50:00, Total trades: 2, Net profit: -1098.8999999999767
# Starting day trading for date: 2025-11-28 00:00:00
# dict_keys([])
# At time 10:35:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:35:00 as net profit 0 > RPT 500.0 in ---- M&M
# dict_keys(['M&M'])
# At time 10:45:00, Total trades: 1, Net profit: -290.0
# Placing 2rd trade at time 10:45:00 as net profit -290.0 > RPT 500.0 in ---- HINDCOPPER
# dict_keys(['M&M', 'HINDCOPPER'])
# At time 11:10:00, Total trades: 2, Net profit: 681.0999999999963
# dict_keys(['M&M', 'HINDCOPPER'])
# At time 11:45:00, Total trades: 2, Net profit: 109.35000000002196
# Starting day trading for date: 2025-11-29 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-11-29 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-11-30 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-11-30 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-01 00:00:00
# dict_keys([])
# At time 11:40:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 11:40:00 as net profit 0 > RPT 500.0 in ---- HDFCBANK
# dict_keys(['HDFCBANK'])
# At time 11:45:00, Total trades: 1, Net profit: 724.9999999999943
# Placing 2rd trade at time 11:45:00 as net profit 724.9999999999943 > RPT 500.0 in ---- LUPIN
# dict_keys(['HDFCBANK', 'LUPIN'])
# At time 13:20:00, Total trades: 2, Net profit: -354.59999999999627
# dict_keys(['HDFCBANK', 'LUPIN'])
# At time 13:25:00, Total trades: 2, Net profit: -154.59999999997922
# dict_keys(['HDFCBANK', 'LUPIN'])
# At time 13:55:00, Total trades: 2, Net profit: -379.60000000000196
# dict_keys(['HDFCBANK', 'LUPIN'])
# At time 14:40:00, Total trades: 2, Net profit: -54.5999999999849
# dict_keys(['HDFCBANK', 'LUPIN'])
# At time 14:40:00, Total trades: 2, Net profit: -54.5999999999849
# dict_keys(['HDFCBANK', 'LUPIN'])
# At time 14:50:00, Total trades: 2, Net profit: 145.40000000000373
# Starting day trading for date: 2025-12-02 00:00:00
# dict_keys([])
# At time 11:40:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 11:40:00 as net profit 0 > RPT 500.0 in ---- ABBOTINDIA
# Starting day trading for date: 2025-12-03 00:00:00
# dict_keys([])
# At time 10:15:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:15:00 as net profit 0 > RPT 500.0 in ---- GLAND
# dict_keys(['GLAND'])
# At time 10:45:00, Total trades: 1, Net profit: 987.8999999999849
# Placing 2rd trade at time 10:45:00 as net profit 987.8999999999849 > RPT 500.0 in ---- ABBOTINDIA
# dict_keys(['GLAND', 'ABBOTINDIA'])
# At time 10:45:00, Total trades: 2, Net profit: 987.8999999999849
# dict_keys(['GLAND', 'ABBOTINDIA'])
# At time 11:00:00, Total trades: 2, Net profit: 2655.09999999999
# Placing 3rd trade at time 11:00:00 as net profit 2655.09999999999 > RPT 1000.0 in ---- M&M
# dict_keys(['GLAND', 'ABBOTINDIA', 'M&M'])
# At time 11:00:00, Total trades: 3, Net profit: 2700.09999999999
# Placing 4rd trade at time 11:00:00 as net profit 2700.09999999999 > RPT 2000.0 in ---- FORTIS
# dict_keys(['GLAND', 'ABBOTINDIA', 'M&M', 'FORTIS'])
# At time 11:15:00, Total trades: 4, Net profit: 2967.8999999999824
# dict_keys(['GLAND', 'ABBOTINDIA', 'M&M', 'FORTIS'])
# At time 11:15:00, Total trades: 4, Net profit: 2967.8999999999824
# dict_keys(['GLAND', 'ABBOTINDIA', 'M&M', 'FORTIS'])
# At time 11:15:00, Total trades: 4, Net profit: 2967.8999999999824
# Starting day trading for date: 2025-12-04 00:00:00
# dict_keys([])
# At time 10:25:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:25:00 as net profit 0 > RPT 500.0 in ---- HINDCOPPER
# dict_keys(['HINDCOPPER'])
# At time 13:20:00, Total trades: 1, Net profit: 1510.5999999999945
# Placing 2rd trade at time 13:20:00 as net profit 1510.5999999999945 > RPT 500.0 in ---- JBCHEPHARM
# dict_keys(['HINDCOPPER', 'JBCHEPHARM'])
# At time 14:25:00, Total trades: 2, Net profit: 733.2000000000071
# Starting day trading for date: 2025-12-05 00:00:00
# dict_keys([])
# At time 10:00:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:00:00 as net profit 0 > RPT 500.0 in ---- CHOLAFIN
# dict_keys(['CHOLAFIN'])
# At time 11:00:00, Total trades: 1, Net profit: -71.99999999999591
# Placing 2rd trade at time 11:00:00 as net profit -71.99999999999591 > RPT 500.0 in ---- BAJFINANCE
# dict_keys(['CHOLAFIN', 'BAJFINANCE'])
# At time 11:00:00, Total trades: 2, Net profit: 193.599999999989
# dict_keys(['CHOLAFIN', 'BAJFINANCE'])
# At time 11:10:00, Total trades: 2, Net profit: 1000.3999999999787
# Placing 3rd trade at time 11:10:00 as net profit 1000.3999999999787 > RPT 1000.0 in ---- NATIONALUM
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 11:10:00, Total trades: 3, Net profit: 1000.3999999999787
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 11:40:00, Total trades: 3, Net profit: 273.3999999999701
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 11:40:00, Total trades: 3, Net profit: 273.3999999999701
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 12:05:00, Total trades: 3, Net profit: -46.20000000000755
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 12:05:00, Total trades: 3, Net profit: -46.20000000000755
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 12:40:00, Total trades: 3, Net profit: 983.5999999999763
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 12:40:00, Total trades: 3, Net profit: 983.5999999999763
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 12:40:00, Total trades: 3, Net profit: 983.5999999999763
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 12:45:00, Total trades: 3, Net profit: 1256.00000000001
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 13:15:00, Total trades: 3, Net profit: 1153.7999999999881
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 13:20:00, Total trades: 3, Net profit: 1483.5999999999963
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 15:00:00, Total trades: 3, Net profit: 101.59999999998058
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 15:00:00, Total trades: 3, Net profit: 101.59999999998058
# dict_keys(['CHOLAFIN', 'BAJFINANCE', 'NATIONALUM'])
# At time 15:00:00, Total trades: 3, Net profit: 101.59999999998058
# Starting day trading for date: 2025-12-06 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-06 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-07 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-07 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-08 00:00:00
# dict_keys([])
# At time 10:25:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:25:00 as net profit 0 > RPT 500.0 in ---- HINDCOPPER
# dict_keys(['HINDCOPPER'])
# At time 10:55:00, Total trades: 1, Net profit: -381.8000000000019
# Placing 2rd trade at time 10:55:00 as net profit -381.8000000000019 > RPT 500.0 in ---- TIINDIA
# dict_keys(['HINDCOPPER', 'TIINDIA'])
# At time 10:55:00, Total trades: 2, Net profit: -264.7999999999855
# dict_keys(['HINDCOPPER', 'TIINDIA'])
# At time 11:15:00, Total trades: 2, Net profit: -112.79999999998552
# dict_keys(['HINDCOPPER', 'TIINDIA'])
# At time 11:15:00, Total trades: 2, Net profit: -112.79999999998552
# dict_keys(['HINDCOPPER', 'TIINDIA'])
# At time 11:35:00, Total trades: 2, Net profit: 343.9000000000208
# dict_keys(['HINDCOPPER', 'TIINDIA'])
# At time 12:00:00, Total trades: 2, Net profit: 980.6000000000365
# dict_keys(['HINDCOPPER', 'TIINDIA'])
# At time 12:05:00, Total trades: 2, Net profit: 1262.3000000000102
# Placing 3rd trade at time 12:05:00 as net profit 1262.3000000000102 > RPT 1000.0 in ---- FORTIS
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS'])
# At time 12:10:00, Total trades: 3, Net profit: 1634.1000000000283
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS'])
# At time 12:15:00, Total trades: 3, Net profit: 2975.049999999986
# Placing 4rd trade at time 12:15:00 as net profit 2975.049999999986 > RPT 2000.0 in ---- OFSS
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS'])
# At time 12:30:00, Total trades: 4, Net profit: 3664.9000000000233
# Placing 5rd trade at time 12:30:00 as net profit 3664.9000000000233 > RPT 3000.0 in ---- NATCOPHARM
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM'])
# At time 12:50:00, Total trades: 5, Net profit: 5857.349999999966
# Placing 6rd trade at time 12:50:00 as net profit 5857.349999999966 > RPT 3000.0 in ---- DIVISLAB
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# dict_keys(['HINDCOPPER', 'TIINDIA', 'FORTIS', 'OFSS', 'NATCOPHARM', 'DIVISLAB'])
# Starting day trading for date: 2025-12-09 00:00:00
# dict_keys([])
# At time 10:15:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:15:00 as net profit 0 > RPT 500.0 in ---- RBLBANK
# dict_keys(['RBLBANK'])
# At time 10:15:00, Total trades: 1, Net profit: 49.80000000000189
# Placing 2rd trade at time 10:15:00 as net profit 49.80000000000189 > RPT 500.0 in ---- SHRIRAMFIN
# dict_keys(['RBLBANK', 'SHRIRAMFIN'])
# At time 10:55:00, Total trades: 2, Net profit: 223.39999999999748
# dict_keys(['RBLBANK', 'SHRIRAMFIN'])
# At time 11:10:00, Total trades: 2, Net profit: 800.15
# dict_keys(['RBLBANK', 'SHRIRAMFIN'])
# At time 11:10:00, Total trades: 2, Net profit: 800.15
# dict_keys(['RBLBANK', 'SHRIRAMFIN'])
# At time 11:15:00, Total trades: 2, Net profit: 739.2499999999987
# dict_keys(['RBLBANK', 'SHRIRAMFIN'])
# At time 11:30:00, Total trades: 2, Net profit: 1056.600000000005
# Placing 3rd trade at time 11:30:00 as net profit 1056.600000000005 > RPT 1000.0 in ---- HINDZINC
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 11:35:00, Total trades: 3, Net profit: 1038.9499999999962
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 11:35:00, Total trades: 3, Net profit: 1038.9499999999962
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 11:55:00, Total trades: 3, Net profit: 125.99999999999841
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 11:55:00, Total trades: 3, Net profit: 125.99999999999841
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 11:55:00, Total trades: 3, Net profit: 125.99999999999841
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 12:05:00, Total trades: 3, Net profit: 115.10000000000218
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 12:05:00, Total trades: 3, Net profit: 115.10000000000218
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 12:05:00, Total trades: 3, Net profit: 115.10000000000218
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 12:05:00, Total trades: 3, Net profit: 115.10000000000218
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 12:05:00, Total trades: 3, Net profit: 115.10000000000218
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 12:45:00, Total trades: 3, Net profit: 141.89999999999588
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 13:05:00, Total trades: 3, Net profit: 191.60000000000093
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 13:25:00, Total trades: 3, Net profit: 490.1999999999965
# dict_keys(['RBLBANK', 'SHRIRAMFIN', 'HINDZINC'])
# At time 13:25:00, Total trades: 3, Net profit: 490.1999999999965
# Starting day trading for date: 2025-12-10 00:00:00
# dict_keys([])
# At time 10:20:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:20:00 as net profit 0 > RPT 500.0 in ---- HINDZINC
# dict_keys(['HINDZINC'])
# At time 11:45:00, Total trades: 1, Net profit: -825.0000000000028
# Placing 2rd trade at time 11:45:00 as net profit -825.0000000000028 > RPT 500.0 in ---- PERSISTENT
# dict_keys(['HINDZINC', 'PERSISTENT'])
# At time 12:25:00, Total trades: 2, Net profit: 151.49999999999716
# dict_keys(['HINDZINC', 'PERSISTENT'])
# At time 13:45:00, Total trades: 2, Net profit: 2104.4999999999973
# Placing 3rd trade at time 13:45:00 as net profit 2104.4999999999973 > RPT 1000.0 in ---- OFSS
# dict_keys(['HINDZINC', 'PERSISTENT', 'OFSS'])
# At time 14:15:00, Total trades: 3, Net profit: 2314.4999999999973
# Placing 4rd trade at time 14:15:00 as net profit 2314.4999999999973 > RPT 2000.0 in ---- TIINDIA
# dict_keys(['HINDZINC', 'PERSISTENT', 'OFSS', 'TIINDIA'])
# At time 14:20:00, Total trades: 4, Net profit: 3712.0999999999935
# Placing 5rd trade at time 14:20:00 as net profit 3712.0999999999935 > RPT 3000.0 in ---- COFORGE
# dict_keys(['HINDZINC', 'PERSISTENT', 'OFSS', 'TIINDIA', 'COFORGE'])
# At time 14:40:00, Total trades: 5, Net profit: 5257.299999999994
# Placing 6rd trade at time 14:40:00 as net profit 5257.299999999994 > RPT 3000.0 in ---- HINDCOPPER
# dict_keys(['HINDZINC', 'PERSISTENT', 'OFSS', 'TIINDIA', 'COFORGE', 'HINDCOPPER'])
# Starting day trading for date: 2025-12-11 00:00:00
# dict_keys([])
# At time 10:30:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:30:00 as net profit 0 > RPT 500.0 in ---- HDFCAMC
# dict_keys(['HDFCAMC'])
# At time 11:35:00, Total trades: 1, Net profit: -330.5999999999931
# Placing 2rd trade at time 11:35:00 as net profit -330.5999999999931 > RPT 500.0 in ---- BANDHANBNK
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 12:00:00, Total trades: 2, Net profit: -199.19999999998163
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 12:00:00, Total trades: 2, Net profit: -199.19999999998163
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 12:00:00, Total trades: 2, Net profit: -199.19999999998163
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 12:15:00, Total trades: 2, Net profit: -51.19999999999641
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 12:25:00, Total trades: 2, Net profit: 48.20000000000459
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 12:25:00, Total trades: 2, Net profit: 48.20000000000459
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 12:40:00, Total trades: 2, Net profit: -121.19999999998959
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 12:40:00, Total trades: 2, Net profit: -121.19999999998959
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 12:40:00, Total trades: 2, Net profit: -121.19999999998959
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 12:40:00, Total trades: 2, Net profit: -121.19999999998959
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 12:45:00, Total trades: 2, Net profit: 100.39999999999782
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 13:30:00, Total trades: 2, Net profit: -1185.3999999999942
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 13:50:00, Total trades: 2, Net profit: -1185.3999999999942
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 14:30:00, Total trades: 2, Net profit: -672.3999999999942
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 15:00:00, Total trades: 2, Net profit: -269.59999999999764
# dict_keys(['HDFCAMC', 'BANDHANBNK'])
# At time 15:00:00, Total trades: 2, Net profit: -269.59999999999764
# Starting day trading for date: 2025-12-12 00:00:00
# dict_keys([])
# At time 10:35:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:35:00 as net profit 0 > RPT 500.0 in ---- RBLBANK
# dict_keys(['RBLBANK'])
# At time 11:25:00, Total trades: 1, Net profit: -210.00000000000227
# Placing 2rd trade at time 11:25:00 as net profit -210.00000000000227 > RPT 500.0 in ---- HINDZINC
# dict_keys(['RBLBANK', 'HINDZINC'])
# At time 12:30:00, Total trades: 2, Net profit: 700.0
# dict_keys(['RBLBANK', 'HINDZINC'])
# At time 13:40:00, Total trades: 2, Net profit: 2410.0000000000023
# Placing 3rd trade at time 13:40:00 as net profit 2410.0000000000023 > RPT 1000.0 in ---- NMDC
# dict_keys(['RBLBANK', 'HINDZINC', 'NMDC'])
# At time 13:45:00, Total trades: 3, Net profit: 2400.0
# Placing 4rd trade at time 13:45:00 as net profit 2400.0 > RPT 2000.0 in ---- HINDALCO
# dict_keys(['RBLBANK', 'HINDZINC', 'NMDC', 'HINDALCO'])
# At time 14:00:00, Total trades: 4, Net profit: 2436.1999999999944
# dict_keys(['RBLBANK', 'HINDZINC', 'NMDC', 'HINDALCO'])
# At time 14:05:00, Total trades: 4, Net profit: 2898.9999999999973
# Starting day trading for date: 2025-12-13 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-13 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-14 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-14 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-15 00:00:00
# dict_keys([])
# At time 10:05:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:05:00 as net profit 0 > RPT 500.0 in ---- HINDZINC
# dict_keys(['HINDZINC'])
# At time 13:05:00, Total trades: 1, Net profit: -937.2000000000032
# Placing 2rd trade at time 13:05:00 as net profit -937.2000000000032 > RPT 500.0 in ---- IDFCFIRSTB
# dict_keys(['HINDZINC', 'IDFCFIRSTB'])
# At time 13:45:00, Total trades: 2, Net profit: -1227.2000000000094
# Starting day trading for date: 2025-12-16 00:00:00
# dict_keys([])
# At time 11:45:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 11:45:00 as net profit 0 > RPT 500.0 in ---- AXISBANK
# dict_keys(['AXISBANK'])
# At time 11:55:00, Total trades: 1, Net profit: -332.0
# Placing 2rd trade at time 11:55:00 as net profit -332.0 > RPT 500.0 in ---- NMDC
# dict_keys(['AXISBANK', 'NMDC'])
# At time 13:15:00, Total trades: 2, Net profit: -849.3999999999677
# dict_keys(['AXISBANK', 'NMDC'])
# At time 13:20:00, Total trades: 2, Net profit: -839.3999999999768
# dict_keys(['AXISBANK', 'NMDC'])
# At time 14:35:00, Total trades: 2, Net profit: -1229.3999999999774
# Starting day trading for date: 2025-12-17 00:00:00
# dict_keys([])
# At time 11:25:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 11:25:00 as net profit 0 > RPT 500.0 in ---- SBILIFE
# dict_keys(['SBILIFE'])
# At time 12:00:00, Total trades: 1, Net profit: 383.40000000000646
# Placing 2rd trade at time 12:00:00 as net profit 383.40000000000646 > RPT 500.0 in ---- HDFCBANK
# dict_keys(['SBILIFE', 'HDFCBANK'])
# At time 12:10:00, Total trades: 2, Net profit: 644.9000000000119
# dict_keys(['SBILIFE', 'HDFCBANK'])
# At time 12:25:00, Total trades: 2, Net profit: 769.2999999999968
# dict_keys(['SBILIFE', 'HDFCBANK'])
# At time 13:30:00, Total trades: 2, Net profit: 1365.0
# Placing 3rd trade at time 13:30:00 as net profit 1365.0 > RPT 1000.0 in ---- MUTHOOTFIN
# dict_keys(['SBILIFE', 'HDFCBANK', 'MUTHOOTFIN'])
# At time 13:35:00, Total trades: 3, Net profit: 1978.0
# dict_keys(['SBILIFE', 'HDFCBANK', 'MUTHOOTFIN'])
# At time 13:35:00, Total trades: 3, Net profit: 1978.0
# dict_keys(['SBILIFE', 'HDFCBANK', 'MUTHOOTFIN'])
# At time 14:05:00, Total trades: 3, Net profit: 589.1000000000209
# dict_keys(['SBILIFE', 'HDFCBANK', 'MUTHOOTFIN'])
# At time 14:35:00, Total trades: 3, Net profit: 744.299999999986
# dict_keys(['SBILIFE', 'HDFCBANK', 'MUTHOOTFIN'])
# At time 14:35:00, Total trades: 3, Net profit: 744.299999999986
# Starting day trading for date: 2025-12-18 00:00:00
# dict_keys([])
# At time 11:45:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 11:45:00 as net profit 0 > RPT 500.0 in ---- AUROPHARMA
# dict_keys(['AUROPHARMA'])
# At time 11:50:00, Total trades: 1, Net profit: 188.70000000000505
# Placing 2rd trade at time 11:50:00 as net profit 188.70000000000505 > RPT 500.0 in ---- APLAPOLLO
# dict_keys(['AUROPHARMA', 'APLAPOLLO'])
# At time 11:50:00, Total trades: 2, Net profit: 354.70000000000505
# dict_keys(['AUROPHARMA', 'APLAPOLLO'])
# At time 12:25:00, Total trades: 2, Net profit: 273.5000000000025
# dict_keys(['AUROPHARMA', 'APLAPOLLO'])
# At time 12:35:00, Total trades: 2, Net profit: 370.8999999999962
# dict_keys(['AUROPHARMA', 'APLAPOLLO'])
# At time 14:35:00, Total trades: 2, Net profit: -973.7999999999975
# dict_keys(['AUROPHARMA', 'APLAPOLLO'])
# At time 15:00:00, Total trades: 2, Net profit: -367.89999999998236
# Starting day trading for date: 2025-12-19 00:00:00
# dict_keys([])
# At time 10:40:00, Total trades: 0, Net profit: 0
# Placing 1rd trade at time 10:40:00 as net profit 0 > RPT 500.0 in ---- MOTHERSON
# dict_keys(['MOTHERSON'])
# At time 11:45:00, Total trades: 1, Net profit: -690.0000000000119
# Placing 2rd trade at time 11:45:00 as net profit -690.0000000000119 > RPT 500.0 in ---- SYNGENE
# dict_keys(['MOTHERSON', 'SYNGENE'])
# At time 11:55:00, Total trades: 2, Net profit: -352.50000000000625
# dict_keys(['MOTHERSON', 'SYNGENE'])
# At time 11:55:00, Total trades: 2, Net profit: -352.50000000000625
# dict_keys(['MOTHERSON', 'SYNGENE'])
# At time 13:30:00, Total trades: 2, Net profit: -1114.999999999995
# dict_keys(['MOTHERSON', 'SYNGENE'])
# At time 13:40:00, Total trades: 2, Net profit: -1177.499999999995
# dict_keys(['MOTHERSON', 'SYNGENE'])
# At time 14:15:00, Total trades: 2, Net profit: -1102.5000000000064
# dict_keys(['MOTHERSON', 'SYNGENE'])
# At time 14:35:00, Total trades: 2, Net profit: -827.5000000000006
# Starting day trading for date: 2025-12-20 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-20 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-21 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-21 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-22 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-22 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-23 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-23 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-24 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-24 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-25 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-25 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-26 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-26 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-27 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-27 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-28 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-28 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-29 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-29 00:00:00: may be a holiday check again
# Starting day trading for date: 2025-12-30 00:00:00
# XXXXXXXXXXXXXXXXXXXXXXXXXXX
#  No index data for 2025-12-30 00:00:00: may be a holiday check again

# %%
df = pd.DataFrame(newhistory)
print(df)
df['profit'] = df['profit']
df['profit'].cumsum().plot()
# Out:
#        entry       sl   target       date                time  status  \
# 0     139.75   138.28   144.16 2025-11-03 2025-12-19 11:10:00   False
# 1    1305.60  1298.00  1328.40 2025-11-03 2025-12-19 12:45:00    True
# 2    1891.00  1912.20  1827.40 2025-11-04 2025-12-19 10:10:00   False
# 3     335.20   336.35   331.75 2025-11-04 2025-12-19 10:40:00   False
# 4     325.55   327.45   319.85 2025-11-06 2025-12-19 10:05:00    True
# ..       ...      ...      ...        ...                 ...     ...
# 97   3769.60  3782.60  3730.60 2025-12-17 2025-12-19 13:30:00    True
# 98   1212.00  1203.90  1236.30 2025-12-18 2025-12-19 11:45:00   False
# 99   1790.00  1778.40  1824.80 2025-12-18 2025-12-19 11:50:00    True
# 100   120.15   119.46   122.22 2025-12-19 2025-12-19 10:40:00   False
# 101   648.35   651.55   638.75 2025-12-19 2025-12-19 11:45:00   False
#
#         side  quantity  profit  exit_price            notes       stock
# 0    bullish     500.0  -735.0      138.28           sl hit        SAIL
# 1    bullish     125.0   550.0         NaN              NaN     IPCALAB
# 2    bearish      45.0  -954.0     1912.20           sl hit       GLAND
# 3    bearish     500.0  1725.0      331.75  target achieved  HINDCOPPER
# 4    bearish     500.0  1075.0         NaN              NaN  HINDCOPPER
# ..       ...       ...     ...         ...              ...         ...
# 97   bearish      76.0   136.8         NaN              NaN  MUTHOOTFIN
# 98   bullish     111.0  -899.1     1203.90           sl hit  AUROPHARMA
# 99   bullish      83.0   531.2         NaN              NaN   APLAPOLLO
# 100  bullish    1000.0  -690.0      119.46           sl hit   MOTHERSON
# 101  bearish     250.0  -800.0      651.55           sl hit     SYNGENE
#
# [102 rows x 12 columns]
# <Axes: >

# %%
import matplotlib.pyplot as plt
def study(history):
    df = pd.DataFrame(history)
    df['date'] = pd.to_datetime(df['date'])
    df = df.sort_values('date')
    daily = df.groupby('date', as_index=True)['profit'].sum()
    daily_cum = daily.cumsum()
    print(daily_cum)
    daily_cum['profit'].plot(figsize=(10, 5), title='Cumulative Profit Over Time')
    plt.xlabel('Date')
    plt.ylabel('Profit')
    plt.show()

    # Option 2: Pass x and y explicitly
    df.plot(x='date', y='profit', figsize=(10, 5))
    plt.xlabel('Date')
    plt.ylabel('Profit')

    return df


study(newhistory)

# %%
END_DATE = datetime(2025, 12, 17, 15, 30)
stock = 'SBILIFE'
df = dataset.get_data(stream, 'NSE', stock, utils.get_token(EXCHANGE, stock + '-EQ'), START_DATE, END_DATE, INTERVAL)
df = Indicators.ema(df, 9)
df = Indicators.ema(df, 15)

df = filter_data_by_date(df, END_DATE)
# df = df.iloc[4:,:]
df.reset_index(inplace=True, drop =True)
if df is not None and  len(df) > 0:
    df = Intraday_breakdowns(df, 3)
    print(df.head(50))
    print(df[df['breakdown']])
